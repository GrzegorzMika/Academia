# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.cluster import DBSCAN, KMeans
from sklearn.preprocessing import StandardScaler, FunctionTransformer, MinMaxScaler
import folium

# %%
data = pd.read_csv('models_PM10.csv').drop(['Unnamed: 0'], 1)

# %%
data
# Out:
#      installation  arparams_0  arparams_1  arparams_2  maparams_0  \
# 0            6147    1.443065   -0.588068    0.097338   -0.360950
# 1            6149    0.648340    0.205961   -0.041008    0.194476
# 2            6150    1.537117   -0.735727    0.153060   -0.589202
# 3            6151    0.426180    0.345788    0.040484    0.495050
# 4            6152    0.529541    0.376505   -0.063075    0.458252
# ..            ...         ...         ...         ...         ...
# 753          6116    0.495320    0.429677   -0.029925    0.553285
# 754          8165    0.623914    0.577574   -0.266035    0.697650
# 755         10213    0.090128    0.917463   -0.109479    0.987320
# 756         10216    0.226372    0.798127   -0.111779    0.889810
# 757         10221    0.449943    0.447474   -0.002731    0.587377
#
#      seasonalmaparams_0
# 0             -0.989190
# 1             -0.997324
# 2             -0.997083
# 3             -0.999793
# 4             -0.977355
# ...

# %%
data.describe()
# Out:
#        installation  arparams_0  arparams_1  arparams_2  maparams_0  \
# count    758.000000  758.000000  758.000000  758.000000  758.000000
# mean    4961.069921    0.753999    0.130430   -0.000766    0.209476
# std     3361.317840    0.501279    0.488008    0.098936    0.515861
# min      233.000000   -0.345501   -1.314225   -0.353108   -0.976113
# 25%     2264.250000    0.363851   -0.221630   -0.059810   -0.186965
# 50%     5650.000000    0.667317    0.200260    0.001447    0.304899
# 75%     7861.250000    1.128570    0.531046    0.063898    0.640594
# max    10582.000000    2.039086    0.949439    0.293826    0.998415
#
#        seasonalmaparams_0
# count          758.000000
# mean            -0.988148
# std              0.021419
# min             -0.999999
# 25%             -0.997906
# 50%             -0.996027
# 75%             -0.992528
# max             -0.856710

# %%
plt.plot(data.installation, data.arparams_0, '.', c="#4378BF")
plt.title('arparams_0')
# Out:
# Text(0.5, 1.0, 'arparams_0')

# %%
plt.plot(data.installation, data.arparams_1, '.', c="#4378BF")
plt.title('arparams_1')
# Out:
# Text(0.5, 1.0, 'arparams_1')

# %%
plt.plot(data.installation, data.arparams_2, '.', c="#4378BF")
plt.title('arparams_2')
# Out:
# Text(0.5, 1.0, 'arparams_2')

# %%
plt.plot(data.installation, data.maparams_0, '.', c="#4378BF")
plt.title('maparams_0')
# Out:
# Text(0.5, 1.0, 'maparams_0')

# %%
plt.plot(data.installation, data.seasonalmaparams_0, '.', c="#4378BF")
plt.title('seasonalmaparams_0')
# Out:
# Text(0.5, 1.0, 'seasonalmaparams_0')
